# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
new_cities = []
country = []
date = []
temp = []
humidity = []
lat = []
lng = []
cloudiness = []
wind = []

# %%
record_counter = 0
set_counter = 0

# URL < Weather Map API Call >

weather_api_key = "25691d94d9685987788b6b5fa530cfcf"
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 
print('------------------------')
print('Fetching Data Requests')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    print(url)
    try:
        date.append(response['dt'])
        country.append(response['sys']['country'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
        new_cities.append(city)
    except:
        print("CITY NOT FOUND")
        pass

print('-------------------------')
print('Data Download Complete')
print('-------------------------')
# Out:
# ------------------------
# Fetching Data Requests
# ------------------------
# Processing record 1 of set 0 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 2 of set 0 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 3 of set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 4 of set 0 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 5 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 6 of set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 7 of set 0 | athabasca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 8 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 9 of set 0 | vinh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 10 of set 0 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 11 of set 0 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 12 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 13 of set 0 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 14 of set 0 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 15 of set 0 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 16 of set 0 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 17 of set 0 | krasnyy kut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 18 of set 0 | baraboo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 19 of set 0 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 20 of set 0 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 21 of set 0 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 22 of set 0 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 23 of set 0 | kendari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 24 of set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 25 of set 0 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 26 of set 0 | maamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 27 of set 0 | manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 28 of set 0 | liverpool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 29 of set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 30 of set 0 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 31 of set 0 | tambura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 32 of set 0 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 33 of set 0 | lolua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 34 of set 0 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 35 of set 0 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 36 of set 0 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 37 of set 0 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 38 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 39 of set 0 | kalininsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 40 of set 0 | fukuma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 41 of set 0 | alipur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 42 of set 0 | busia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 43 of set 0 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 44 of set 0 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 45 of set 0 | gijon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 46 of set 0 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 47 of set 0 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 48 of set 0 | san luis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 49 of set 0 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 50 of set 0 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 0 of set 1 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 1 of set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 2 of set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 3 of set 1 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 4 of set 1 | ulety
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 5 of set 1 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 6 of set 1 | panaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 7 of set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 8 of set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 9 of set 1 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 10 of set 1 | trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 11 of set 1 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 12 of set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 13 of set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 14 of set 1 | kitimat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 15 of set 1 | lac du bonnet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 16 of set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 17 of set 1 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 18 of set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 19 of set 1 | huilong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 20 of set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 21 of set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 22 of set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 23 of set 1 | arang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 24 of set 1 | atherton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 25 of set 1 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 26 of set 1 | abay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 27 of set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 28 of set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 29 of set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 30 of set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 31 of set 1 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 32 of set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 33 of set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 34 of set 1 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 35 of set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 36 of set 1 | kuche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 37 of set 1 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 38 of set 1 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 39 of set 1 | poso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 40 of set 1 | nampula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 41 of set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 42 of set 1 | katherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 43 of set 1 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 44 of set 1 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 45 of set 1 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 46 of set 1 | bar harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 47 of set 1 | troitskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 48 of set 1 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 49 of set 1 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 50 of set 1 | glencoe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 0 of set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 1 of set 2 | mamaku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 2 of set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 3 of set 2 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 4 of set 2 | corbelia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 5 of set 2 | muscat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 6 of set 2 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 7 of set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 8 of set 2 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 9 of set 2 | boffa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 10 of set 2 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 11 of set 2 | san vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 12 of set 2 | pehowa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 13 of set 2 | murgab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 14 of set 2 | eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 15 of set 2 | majene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 16 of set 2 | kapoeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 17 of set 2 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 18 of set 2 | atasu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 19 of set 2 | manado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 20 of set 2 | eydhafushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 21 of set 2 | tasbuget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 22 of set 2 | zherdevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 23 of set 2 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 24 of set 2 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 25 of set 2 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 26 of set 2 | burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 27 of set 2 | zaraza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 28 of set 2 | pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 29 of set 2 | wajima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 30 of set 2 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 31 of set 2 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 32 of set 2 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 33 of set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 34 of set 2 | talaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 35 of set 2 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 36 of set 2 | fairview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 37 of set 2 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 38 of set 2 | popondetta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 39 of set 2 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 40 of set 2 | jardim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 41 of set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 42 of set 2 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 43 of set 2 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 44 of set 2 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 45 of set 2 | paso de carrasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 46 of set 2 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 47 of set 2 | milazzo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 48 of set 2 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 49 of set 2 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 50 of set 2 | roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 0 of set 3 | chhatapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 1 of set 3 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 2 of set 3 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 3 of set 3 | minab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 4 of set 3 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 5 of set 3 | dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 6 of set 3 | aitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 7 of set 3 | saryshagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 8 of set 3 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 9 of set 3 | kambia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 10 of set 3 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 11 of set 3 | wegorzewo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 12 of set 3 | letka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 13 of set 3 | dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 14 of set 3 | wahiawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 15 of set 3 | port said
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 16 of set 3 | hohhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 17 of set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 18 of set 3 | boksitogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 19 of set 3 | zapolyarnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 20 of set 3 | koronowo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 21 of set 3 | kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 22 of set 3 | ransang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 23 of set 3 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 24 of set 3 | monroe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 25 of set 3 | karamea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 26 of set 3 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 27 of set 3 | micheweni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 28 of set 3 | emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 29 of set 3 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 30 of set 3 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 31 of set 3 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 32 of set 3 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 33 of set 3 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 34 of set 3 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# CITY NOT FOUND
# Processing record 35 of set 3 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 36 of set 3 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 37 of set 3 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 38 of set 3 | marrakesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 39 of set 3 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 40 of set 3 | piacabucu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 41 of set 3 | cam ranh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 42 of set 3 | george town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 43 of set 3 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 44 of set 3 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 45 of set 3 | srandakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 46 of set 3 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 47 of set 3 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 48 of set 3 | inca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 49 of set 3 | ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 50 of set 3 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 0 of set 4 | council bluffs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 1 of set 4 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 2 of set 4 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 3 of set 4 | barreiras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 4 of set 4 | estelle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 5 of set 4 | port moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 6 of set 4 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 7 of set 4 | isiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 8 of set 4 | durban
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 9 of set 4 | kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 10 of set 4 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 11 of set 4 | hadrut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record 12 of set 4 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25691d94d9685987788b6b5fa530cfcf
# Processing record
# %%
cities_list = zip(new_cities,cloudiness,country,date,humidity,temp,lat,lng)

# Set Output File Variable
output_file = os.path.join('..', 'output_data', 'cities.csv')

# Open Output File
with open(output_file, 'w') as datafile:
    weather_data.to_csv(output_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_data.plot(kind='scatter', x='Lat', y='Temp', c='DarkBlue')
plt.title('City Latitude vs Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.savefig("../output_data/Latitude_vs_Temperature.png")
plt.grid()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_data.plot(kind='scatter',x='Lat',y='Humidity', c='DarkBlue')
plt.title('City Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig("../output_data/Latitude_vs_Humidity.png")
plt.grid()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_data.plot(kind='scatter',x='Lat',y='Cloudiness', c='DarkBlue')
plt.title('City Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig("../output_data/Latitude_vs_Cloudiness.png")
plt.grid()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_data.plot(kind='scatter',x='Lat',y='Wind Speed', c='DarkBlue')
plt.title('City Latitude vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.savefig("../output_data/Latitude_vs_Wind_Speed.png")
plt.grid()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# def make_lin_reg_plot(x_values,y_values,x_desc,y_desc,hemisphere,filename,x_ann,y_ann):
    # Print out the r-squared value along with the plot.
    # (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    # regress_values = x_values * slope + intercept
    # line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # plt.scatter(x_values,y_values,edgecolors='black')
    # plt.plot(x_values,regress_values,"r-")
    # plt.title(f"{hemisphere}-\nCity {x_desc} vs. {y_desc} {weatherDate}")
    # plt.annotate(line_eq,(x_ann,y_ann),fontsize=15,color="red")
    # plt.xlabel(x_desc)
    # plt.ylabel(y_desc)
    # print(f"The r-squared is: {rvalue}")
    # print(line_eq)
    # plt.savefig(f'Figures/{filename}')
    # plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames

North_df = weather_data.loc[weather_data['Lat'] >=0]
South_df = weather_data.loc[weather_data['Lat'] < 0]

North_df.head()

# %%
South_df.head()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = North_df['Lat'].astype('float')
y_values = North_df['Temp'].astype('float')

# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = "R:Value=" + "  " + str(round(rvalue, 2))

# Scatter plot
plt.scatter(x_values,y_values, color="green")

# Regression line
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(5, 25),fontsize=15,color="blue")
plt.annotate(rvalue,(5,17),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f"Northern Hemisphere: Temperature vs Latitude Regression")

plt.grid()
plt.savefig("../output_data/Northern_Hemisphere_Temp_vs_Latitude_Regression.png")
plt.grid()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = South_df['Lat'].astype('float')
y_values = South_df['Temp'].astype('float')

# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = "R:Value=" + "  " + str(round(rvalue, 2))

# Scatter plot
plt.scatter(x_values,y_values, color="green")

# Regression line
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(-50, 85),fontsize=15,color="blue")
plt.annotate(rvalue,(-50, 80),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f"Southern Hemisphere: Max Temp vs Latitude Regression")

plt.grid()
plt.savefig("../output_data/Southern_Hemisphere_Temp_vs_Latitude_Regression.png")
plt.grid()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = North_df['Lat'].astype('float')
y_values = North_df['Humidity'].astype('float')

# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = "R:Value =" + "  " + str(round(rvalue, 2))

# Scatter plot
plt.scatter(x_values,y_values, color="green")

# Regression line
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(48,20),fontsize=15,color="blue")
plt.annotate(rvalue,(48, 10),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f"Northern Hemisphere: Humidity vs Latitude Regression")

plt.grid()
plt.savefig("../output_data/Northern_Hemisphere_Humidity_vs_Latitude_Regression.png")
plt.grid()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = South_df['Lat'].astype('float')
y_values = South_df['Humidity'].astype('float')

# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = "R:Value =" + "  " + str(round(rvalue, 2))

# Scatter plot
plt.scatter(x_values,y_values, color="green")

# Regression line
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(-55,200),fontsize=15,color="blue")
plt.annotate(rvalue,(-55, 175),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f"Southern Hemisphere: Humidity vs Latitude Regression")

plt.grid()
plt.savefig("../output_data/Southern_Hemisphere_Humidity_vs_Latitude_Regression.png")
plt.grid()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = North_df['Lat'].astype('float')
y_values = North_df['Cloudiness'].astype('float')

# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = "R:Value =" + "  " + str(round(rvalue, 2))

# Scatter plot
plt.scatter(x_values,y_values, color="green")

# Regression line
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(25,65),fontsize=15,color="blue")
plt.annotate(rvalue,(25, 55),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f"Northern Hemisphere: Cloudiness vs Latitude Regression")

plt.grid()
plt.savefig("../output_data/Northern_Hemisphere_Cloudiness_vs_Latitude_Regression.png")
plt.grid()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = South_df['Lat'].astype('float')
y_values = South_df['Cloudiness'].astype('float')

# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = "R:Value =" + "  " + str(round(rvalue, 2))

# Scatter plot
plt.scatter(x_values,y_values, color="green")

# Regression line
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(-55,13),fontsize=15,color="blue")
plt.annotate(rvalue,(-55, 3),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f"Southern Hemisphere: Cloudiness vs Latitude Regression")

plt.grid()
plt.savefig("../output_data/Southern_Hemisphere_Cloudiness_vs_Latitude_Regression.png")
plt.grid()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = North_df['Lat'].astype('float')
y_values = North_df['Wind Speed'].astype('float')

# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = "R:Value =" + "  " + str(round(rvalue, 2))

# Scatter plot
plt.scatter(x_values,y_values, color="green")

# Regression line
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(25,65),fontsize=15,color="blue")
plt.annotate(rvalue,(25, 55),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f"Northern Hemisphere: Wind Speed vs Latitude Regression")

plt.grid()
plt.savefig("../output_data/Northern_Hemisphere_Wind_Speed_vs_Latitude_Regression.png")
plt.grid()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = South_df['Wind Speed'].astype('float')
y_values = South_df['Cloudiness'].astype('float')

# Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = "R:Value =" + "  " + str(round(rvalue, 2))

# Scatter plot
plt.scatter(x_values,y_values, color="green")

# Regression line
plt.plot(x_values,regress_values,"b-")
plt.annotate(line_eq,(-55,13),fontsize=15,color="blue")
plt.annotate(rvalue,(-55, 3),fontsize=15,color="red")

# Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f"Southern Hemisphere: Wind Speed vs Latitude Regression")

plt.grid()
plt.savefig("../output_data/Southern_Hemisphere_Wind_Speed_vs_Latitude_Regression.png")
